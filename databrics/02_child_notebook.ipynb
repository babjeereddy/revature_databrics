# %%
lst =[10,20,30,40]
result = list(map(lambda x: x * x, lst))
print(result)
# Out:
# [100, 400, 900, 1600]

# %%
# %sql
select current_user()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_user()</th></tr></thead><tbody><tr><td>babjee@babjeepranathigmail.onmicrosoft.com</td></tr></tbody></table></div>

# %%
# %scala
print("this is scala command")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">this is scala command</div>
