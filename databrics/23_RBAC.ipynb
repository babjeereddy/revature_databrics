-- %%
GRANT USE CATALOG ON CATALOG project  to `dbx-data-engineers`;

-- %%
GRANT USE SCHEMA ON SCHEMA project.gold TO `dbx-data-engineers`;

-- %%
show grants on schema project.gold
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody><tr><td>dbx-data-engineers</td><td>USE SCHEMA</td><td>SCHEMA</td><td>project.gold</td></tr></tbody></table></div>

-- %%
grant select on project.gold.silver_customers to `dbx-data-engineers`;

-- %%
grant modify on table project.gold.silver_customers to `dbx-data-engineers`;

-- %%
revoke modify on table project.gold.silver_customers from  `dbx-data-engineers`;

-- %%
grant select, modify on schema project.silver to `dbx-data-engineers`;

-- %%
grant create table on schema project.gold to `dbx-data-engineers`;

-- %%
%sql
show grants on schema project.gold;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody><tr><td>dbx-data-engineers</td><td>CREATE TABLE</td><td>SCHEMA</td><td>project.gold</td></tr><tr><td>dbx-data-engineers</td><td>USE SCHEMA</td><td>SCHEMA</td><td>project.gold</td></tr></tbody></table></div>

-- %%
%sql
grant select on schema project.gold to `dbx-data-engineers`;

-- %%
GRANT CREATE TABLE, MODIFY
ON SCHEMA project.bronze
TO `dbx-data-engineers`;

-- %%
show grants on schema project.bronze
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody><tr><td>dbx-data-engineers</td><td>CREATE TABLE</td><td>SCHEMA</td><td>project.bronze</td></tr><tr><td>dbx-data-engineers</td><td>MODIFY</td><td>SCHEMA</td><td>project.bronze</td></tr><tr><td>dbx-data-engineers</td><td>USE SCHEMA</td><td>SCHEMA</td><td>project.bronze</td></tr></tbody></table></div>

-- %%
show tables in project.bronze
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
GRANT SELECT ON TABLE project.bronze.customers_raw TO `dbx-data-engineers`

-- %%
GRANT SELECT ON SCHEMA project.bronze TO `dbx-data-engineers`

-- %%
show storage credentials
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>comment</th></tr></thead><tbody><tr><td>training_ws</td><td>null</td></tr><tr><td>trainingbr-credential</td><td>null</td></tr></tbody></table></div>

-- %%
GRANT CREATE EXTERNAL LOCATION ON STORAGE CREDENTIAL `trainingbr-credential`
TO `dbx-data-engineers`;

-- %%
GRANT CREATE EXTERNAL LOCATION ON METASTORE TO `dbx-data-engineers`;

-- %%
drop external location trainingbr_loc;

-- %%
show external locations
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
GRANT READ FILES, WRITE FILES
ON EXTERNAL LOCATION project
TO `project`;
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-5129622597544446>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', 'GRANT READ FILES, WRITE FILES\nON EXTERNAL LOCATION raw_data\nTO `project`;\n')
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- ...

-- %%
grant create catalog on metastore to `dbx-data-engineers`;

-- %%
desc catalog extended project
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
