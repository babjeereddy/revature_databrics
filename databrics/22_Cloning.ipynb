# %%
# %sql
USE CATALOG project; USE SCHEMA bronze;

# %%
# %sql
CREATE TABLE customers_clone
SHALLOW CLONE project.bronze.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_table_size</th><th>source_num_of_files</th><th>num_of_synced_transactions</th><th>num_removed_files</th><th>num_copied_files</th><th>removed_files_size</th><th>copied_files_size</th></tr></thead><tbody><tr><td>3179</td><td>2</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
describe table extended customers_clone
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
describe table extended customers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from project.bronze.customers_clone;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th><th>segment</th></tr></thead><tbody><tr><td>101</td><td>Asha</td><td>Chennai</td><td>Retail</td></tr><tr><td>102</td><td>Bala</td><td>Bengaluru</td><td>SMB</td></tr><tr><td>103</td><td>Charan</td><td>Hyderabad</td><td>Enterprise</td></tr><tr><td>4</td><td>ram</td><td>chennai</td><td>Retail</td></tr></tbody></table></div>

# %%
# %sql
insert into project.bronze.customers_clone values (5,'kiran','mumbai', 'SMB')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT * from project.bronze.customers_clone;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th><th>segment</th></tr></thead><tbody><tr><td>101</td><td>Asha</td><td>Chennai</td><td>Retail</td></tr><tr><td>102</td><td>Bala</td><td>Bengaluru</td><td>SMB</td></tr><tr><td>103</td><td>Charan</td><td>Hyderabad</td><td>Enterprise</td></tr><tr><td>4</td><td>ram</td><td>chennai</td><td>Retail</td></tr><tr><td>5</td><td>kiran</td><td>mumbai</td><td>SMB</td></tr></tbody></table></div>

# %%
# %sql
select * from bronze.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th><th>segment</th></tr></thead><tbody><tr><td>101</td><td>Asha</td><td>Chennai</td><td>Retail</td></tr><tr><td>102</td><td>Bala</td><td>Bengaluru</td><td>SMB</td></tr><tr><td>103</td><td>Charan</td><td>Hyderabad</td><td>Enterprise</td></tr><tr><td>6</td><td>praveen</td><td>chennai</td><td>SMB</td></tr><tr><td>4</td><td>ram</td><td>chennai</td><td>Retail</td></tr></tbody></table></div>

# %%
# %sql
insert into customers values(6,'praveen','chennai', 'SMB')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
create table customers_deep_clone
deep clone customers

# %%
# %sql
select * from  customers_clone;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th><th>segment</th></tr></thead><tbody><tr><td>101</td><td>Asha</td><td>Chennai</td><td>Retail</td></tr><tr><td>102</td><td>Bala</td><td>Bengaluru</td><td>SMB</td></tr><tr><td>103</td><td>Charan</td><td>Hyderabad</td><td>Enterprise</td></tr><tr><td>4</td><td>ram</td><td>chennai</td><td>Retail</td></tr><tr><td>5</td><td>kiran</td><td>mumbai</td><td>SMB</td></tr></tbody></table></div>

# %%
# %sql
describe history customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
describe history customers_clone;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
create table customers__deep_clone
deep clone customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_table_size</th><th>source_num_of_files</th><th>num_of_synced_transactions</th><th>num_removed_files</th><th>num_copied_files</th><th>removed_files_size</th><th>copied_files_size</th></tr></thead><tbody><tr><td>4745</td><td>3</td><td>null</td><td>0</td><td>3</td><td>0</td><td>4745</td></tr></tbody></table></div>

# %%
# %sql
select * from customers__deep_clone;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th><th>segment</th></tr></thead><tbody><tr><td>101</td><td>Asha</td><td>Chennai</td><td>Retail</td></tr><tr><td>102</td><td>Bala</td><td>Bengaluru</td><td>SMB</td></tr><tr><td>103</td><td>Charan</td><td>Hyderabad</td><td>Enterprise</td></tr><tr><td>6</td><td>praveen</td><td>chennai</td><td>SMB</td></tr><tr><td>4</td><td>ram</td><td>chennai</td><td>Retail</td></tr></tbody></table></div>

# %%
# %sql
desc extended customers__deep_clone;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
drop table customers;

# %%
# %sql
describe detail customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
delete from customers where customer_id = 6;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>
