-- %%
use catalog project;
CREATE TABLE bronze.sales_lc (
  order_id LONG,
  order_date DATE,
  customer_id STRING,
  amount DOUBLE
)
USING DELTA
CLUSTER BY (customer_id, order_date);

-- %%
insert into bronze.sales_lc values
(1,current_date(), 'customer_1', 100.00),
(2,current_date(), 'customer_2', 200.00),
(1,current_date(), 'customer_1', 100.00),
(2,current_date(), 'customer_2', 200.00),
(3,current_date(), 'customer_3', 300.00),
(4,current_date(), 'customer_4', 400.00),
(5,current_date(), 'customer_5', 500.00),
(1  ,current_date(), 'customer_1', 100.00),
(7,current_date(), 'customer_2', 200.00),
(8,current_date(), 'customer_3', 300.0) ,
(9,current_date(), 'customer_4', 400.00),
(10,current_date(), 'customer_5', 500.00),
(11,current_date(), 'customer_1', 2000.0)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>13</td><td>13</td></tr></tbody></table></div>

-- %%
select * from bronze.sales_lc where customer_id = 'customer_1' and order_id=1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>customer_id</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>2025-12-13</td><td>customer_1</td><td>100.0</td></tr><tr><td>1</td><td>2025-12-13</td><td>customer_1</td><td>100.0</td></tr><tr><td>1</td><td>2025-12-13</td><td>customer_1</td><td>100.0</td></tr></tbody></table></div>

-- %%
describe table silver.sales_delta;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>sale_id</td><td>int</td><td>null</td></tr><tr><td>product</td><td>string</td><td>null</td></tr><tr><td>quantity</td><td>int</td><td>null</td></tr><tr><td>price</td><td>double</td><td>null</td></tr><tr><td>sale_timestamp</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

-- %%
set spark.databricks.delta.allowArbitraryProperties.enabled=true
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>spark.databricks.delta.allowArbitraryProperties.enabled</td><td>true</td></tr></tbody></table></div>

-- %%
-- Convert an Existing Table to Liquid Clustering
ALTER TABLE silver.sales_delta
CLUSTER BY (sale_id, product);

-- %%
-- Reorganize the Table


OPTIMIZE silver.sales_delta;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
describe table extended silver.sales_delta;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
