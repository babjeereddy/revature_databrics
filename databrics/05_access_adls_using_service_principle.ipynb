# %%
service_credential = "3q18Q~oTk3T1Pp6lukmg0Kl.NTifXAAY4.j1Nbos"

spark.conf.set("fs.azure.account.auth.type.trainingbr.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.trainingbr.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.trainingbr.dfs.core.windows.net", "41439dc6-a861-40c3-96f7-fdf246f845b0")
spark.conf.set("fs.azure.account.oauth2.client.secret.trainingbr.dfs.core.windows.net", service_credential)
spark.conf.set("fs.azure.account.oauth2.client.endpoint.trainingbr.dfs.core.windows.net", "https://login.microsoftonline.com/6a5b4c57-4edd-4bf8-8e21-2a0774c5830d/oauth2/token")

# %%
display(dbutils.fs.ls("abfss://data@trainingbr.dfs.core.windows.net/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://data@trainingbr.dfs.core.windows.net/Orders1</td><td>Orders1</td><td>2999983</td><td>1765177959000</td></tr><tr><td>abfss://data@trainingbr.dfs.core.windows.net/orders/</td><td>orders/</td><td>0</td><td>1765178087000</td></tr></tbody></table></div>

# %%
dbutils.fs.mounts()
# Out:
# [MountInfo(mountPoint='/databricks-datasets', source='databricks-datasets', encryptionType=''),
#  MountInfo(mountPoint='/Volumes', source='UnityCatalogVolumes', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-tracking', source='databricks/mlflow-tracking', encryptionType=''),
#  MountInfo(mountPoint='/databricks-results', source='databricks-results', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-registry', source='databricks/mlflow-registry', encryptionType=''),
#  MountInfo(mountPoint='/Volume', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/volumes', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/', source='DatabricksRoot', encryptionType=''),
#  MountInfo(mountPoint='/volume', source='DbfsReserved', encryptionType='')]

# %%
configs = {
    "fs.azure.account.auth.type": "OAuth",
    "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
    "fs.azure.account.oauth2.client.id": "41439dc6-a861-40c3-96f7-fdf246f845b0",
    "fs.azure.account.oauth2.client.secret": "3q18Q~oTk3T1Pp6lukmg0Kl.NTifXAAY4.j1Nbos",
    "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/6a5b4c57-4edd-4bf8-8e21-2a0774c5830d/oauth2/token"
}

dbutils.fs.mount(
    source="abfss://data@trainingbr.dfs.core.windows.net/",
    mount_point="/mnt/training",
    extra_configs=configs
)
# Out:
# True

# %%
dbutils.fs.ls("/mnt/training")
# Out:
# [FileInfo(path='dbfs:/mnt/training/Orders1', name='Orders1', size=2999983, modificationTime=1765177959000),
#  FileInfo(path='dbfs:/mnt/training/orders/', name='orders/', size=0, modificationTime=1765178087000)]

# %%
dbutils.fs.mounts()
# Out:
# [MountInfo(mountPoint='/mnt/training', source='abfss://data@trainingbr.dfs.core.windows.net/', encryptionType=''),
#  MountInfo(mountPoint='/databricks-datasets', source='databricks-datasets', encryptionType=''),
#  MountInfo(mountPoint='/Volumes', source='UnityCatalogVolumes', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-tracking', source='databricks/mlflow-tracking', encryptionType=''),
#  MountInfo(mountPoint='/databricks-results', source='databricks-results', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-registry', source='databricks/mlflow-registry', encryptionType=''),
#  MountInfo(mountPoint='/Volume', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/volumes', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/', source='DatabricksRoot', encryptionType=''),
#  MountInfo(mountPoint='/volume', source='DbfsReserved', encryptionType='')]

# %%
dbutils.fs.unmount("/mnt/training")

dbutils.fs.mounts()
# Out:
# /mnt/training has been unmounted.
# [MountInfo(mountPoint='/databricks-datasets', source='databricks-datasets', encryptionType=''),
#  MountInfo(mountPoint='/Volumes', source='UnityCatalogVolumes', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-tracking', source='databricks/mlflow-tracking', encryptionType=''),
#  MountInfo(mountPoint='/databricks-results', source='databricks-results', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-registry', source='databricks/mlflow-registry', encryptionType=''),
#  MountInfo(mountPoint='/Volume', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/volumes', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/', source='DatabricksRoot', encryptionType=''),
#  MountInfo(mountPoint='/volume', source='DbfsReserved', encryptionType='')]
