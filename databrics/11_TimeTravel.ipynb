-- %%
drop table project.silver.emp_delta;

-- %%
CREATE OR REPLACE TABLE project.silver.emp_delta (
  id      INT,
  name    STRING,
  dept    STRING,
  salary  INT
) USING DELTA;

-- %%
describe detail project.silver.emp_delta
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
INSERT INTO project.silver.emp_delta VALUES
  (1, 'Ravi',  'IT',       50000),
  (2, 'Priya', 'Finance',  60000),
  (3, 'John',  'HR',       55000);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %%
select current_timestamp();
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_timestamp()</th></tr></thead><tbody><tr><td>2025-12-10T04:20:11.08806Z</td></tr></tbody></table></div>

-- %%
UPDATE project.silver.emp_delta
SET salary = 55000
WHERE id = 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
DELETE FROM project.silver.emp_delta
WHERE id = 3;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
INSERT INTO project.silver.emp_delta VALUES
(4, 'Kiran', 'IT', 65000);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

-- %%
DESCRIBE HISTORY project.silver.emp_delta;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT * FROM project.silver.emp_delta VERSION AS OF 0;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM project.silver.emp_delta VERSION AS OF 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>IT</td><td>50000</td></tr><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>3</td><td>John</td><td>HR</td><td>55000</td></tr></tbody></table></div>

-- %%
select * from project.silver.emp_delta version as of 4;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>1</td><td>Ravi</td><td>IT</td><td>55000</td></tr></tbody></table></div>

-- %%
select * from project.silver.emp_delta version as of 6;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>1</td><td>Ravi</td><td>IT</td><td>55000</td></tr><tr><td>4</td><td>Kiran</td><td>IT</td><td>65000</td></tr></tbody></table></div>

-- %%
select * from project.silver.emp_delta version as of 0
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody></tbody></table></div>

-- %%
select * from project.silver.emp_delta version as of 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>IT</td><td>50000</td></tr><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>3</td><td>John</td><td>HR</td><td>55000</td></tr></tbody></table></div>

-- %%
select * from project.silver.emp_delta version as of 2;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>IT</td><td>55000</td></tr><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>3</td><td>John</td><td>HR</td><td>55000</td></tr></tbody></table></div>

-- %%
%python
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "project.silver.emp_delta")
display(dt.history().show(truncate=False))
-- Out:
-- +-------+-------------------+---------------+------------------------------------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+-----------------+--------------------+-----------+-----------------+-------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
-- ...

-- %%
%python
df_v0_read = spark.read.format("delta").option("versionAsOf", 0).table("project.silver.emp_delta")
df_v0_read.show()
-- Out:
-- +---+----+----+------+
-- | id|name|dept|salary|
-- +---+----+----+------+
-- +---+----+----+------+

-- %%
%python
df_v1_read = spark.read.format("delta").option("versionAsOf", 1).table("project.silver.emp_delta")
df_v1_read.show()
-- Out:
-- +---+-----+-------+------+
-- | id| name|   dept|salary|
-- +---+-----+-------+------+
-- |  1| Ravi|     IT| 50000|
-- |  2|Priya|Finance| 60000|
-- |  3| John|     HR| 55000|
-- +---+-----+-------+------+

-- %%
%python
df_v2_read = spark.read.format("delta").option("versionAsOf", 2).table("project.silver.emp_delta")
df_v2_read.show()
-- Out:
-- +---+-----+-------+------+
-- | id| name|   dept|salary|
-- +---+-----+-------+------+
-- |  1| Ravi|     IT| 55000|
-- |  2|Priya|Finance| 60000|
-- |  3| John|     HR| 55000|
-- +---+-----+-------+------+

-- %%
%python
df_v3_read = spark.read.format("delta").option("versionAsOf", 3).table("project.silver.emp_delta")
df_v3_read.show()
-- Out:
-- +---+-----+-------+------+
-- | id| name|   dept|salary|
-- +---+-----+-------+------+
-- |  2|Priya|Finance| 60000|
-- |  3| John|     HR| 55000|
-- |  1| Ravi|     IT| 55000|
-- +---+-----+-------+------+

-- %%
SELECT * FROM project.silver.emp_delta
TIMESTAMP AS OF '2025-12-10T04:20:11.088+00:00';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>IT</td><td>50000</td></tr><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>3</td><td>John</td><td>HR</td><td>55000</td></tr></tbody></table></div>

-- %%
select * from project.silver.emp_delta;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>1</td><td>Ravi</td><td>IT</td><td>55000</td></tr><tr><td>4</td><td>Kiran</td><td>IT</td><td>65000</td></tr></tbody></table></div>

-- %%
RESTORE TABLE project.silver.emp_delta TO VERSION AS OF 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>1465</td><td>1</td><td>2</td><td>1</td><td>3794</td><td>1465</td></tr></tbody></table></div>

-- %%
select * from project.silver.emp_delta;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>IT</td><td>50000</td></tr><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>3</td><td>John</td><td>HR</td><td>55000</td></tr></tbody></table></div>

-- %%
drop table if exists project.silver.emp_delta;
select * from project.silver.emp_delta;
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-5513995032101630>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', 'drop table if exists project.silver.emp_delta;\nselect * from project.silver.emp_delta;\n')
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- ...

-- %%
undrop table project.silver.emp_delta;

-- %%
select * from project.silver.emp_delta;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>IT</td><td>50000</td></tr><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>3</td><td>John</td><td>HR</td><td>55000</td></tr></tbody></table></div>

-- %%
create table emp_deta1 
as select * from project.silver.emp_delta version as of 1;
select * from emp_deta1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>dept</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>IT</td><td>50000</td></tr><tr><td>2</td><td>Priya</td><td>Finance</td><td>60000</td></tr><tr><td>3</td><td>John</td><td>HR</td><td>55000</td></tr></tbody></table></div>
